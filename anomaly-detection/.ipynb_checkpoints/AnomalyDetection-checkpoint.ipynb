# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("train.csv")

# %%
train.head()
# Out:
#     timestamp  value  is_anomaly  predicted
# 0  1425008573     42       False  44.072500
# 1  1425008873     41       False  50.709390
# 2  1425009173     41       False  81.405120
# 3  1425009473     61       False  39.950367
# 4  1425009773     44       False  35.350160

# %%
train.shape
# Out:
# (15830, 4)

# %%
plt.figure(figsize = (30, 25))
sns.heatmap(train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.isna().sum()
# Out:
# timestamp     0
# value         0
# is_anomaly    0
# predicted     0
# dtype: int64

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
label=train['is_anomaly']
data=train.drop(['is_anomaly'],axis=1)
print(data.shape)
# Out:
# (15830, 3)

# %%
label.value_counts()
# Out:
# False    15054
# True       776
# Name: is_anomaly, dtype: int64

# %%
print(train.isnull().sum())
# Out:
# timestamp     0
# value         0
# is_anomaly    0
# predicted     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = scaler.fit_transform(train)

# %%
from sklearn.ensemble import IsolationForest

clf = IsolationForest(n_estimators=100, contamination='auto', random_state=42)
preds = clf.fit_predict(data_scaled)

# %%
scores = clf.decision_function(data_scaled)
plt.hist(scores, bins=50)
plt.xlabel('Anomaly Score')
plt.ylabel('Frequency')
plt.show()

# %%
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29976\2992420520.py in <module>
# ----> 1 score
#
# NameError: name 'score' is not defined

# %%
anomalies = data_scaled.iloc[preds==-1]
anomalies
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29976\531236349.py in <module>
# ----> 1 anomalies = data_scaled.iloc[preds==-1]
#       2 anomalies
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
anomalies['is_anomaly'] = True
# Out:
# C:\Users\ADMINSTRATOR\AppData\Local\Temp\ipykernel_29976\2164392544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomalies['is_anomaly'] = True

# %%
s = pd.read_csv("submission.csv")

# %%
s
# Out:
#         timestamp  is_anomaly
# 0      1425008573       False
# 1      1425008873       False
# 2      1425009173       False
# 3      1425009473       False
# 4      1425009773       False
# ...           ...         ...
# 15825  1429756073       False
# 15826  1429756373       False
# 15827  1429756673       False
# 15828  1429756973       False
# 15829  1429757273       False
#
# [15830 rows x 2 columns]

# %%
train
# Out:
#         timestamp  value  is_anomaly  predicted
# 0      1425008573     42       False  44.072500
# 1      1425008873     41       False  50.709390
# 2      1425009173     41       False  81.405120
# 3      1425009473     61       False  39.950367
# 4      1425009773     44       False  35.350160
# ...           ...    ...         ...        ...
# 15825  1429756073     44       False  53.624115
# 15826  1429756373     45       False  59.752296
# 15827  1429756673     48       False  52.147630
# 15828  1429756973     26       False  58.007545
# 15829  1429757273     38       False  59.144700
#
# [15830 rows x 4 columns]

# %%
ss = train.merge(anmalies, on='timestamp', how='left', suffixes=('', '_target'))

# Set the values in the 'Value' column of df1 to True where they match the values in df2
merged.loc[merged['is_anomaly'] == merged['Value_target'], 'Value'] = True

# Drop the 'Value_target' column
merged.drop('Value_target', axis=1, inplace=True)
